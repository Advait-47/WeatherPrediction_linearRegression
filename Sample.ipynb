# %%
import pandas as pd

# %%
df=pd.read_csv('sudeste.csv')

# %%
df
# Out:
#          wsid         wsnm   elvt        lat        lon  inme         city  \
# 0         178  SÃO GONÇALO  237.0  -6.835777 -38.311583  A333  São Gonçalo
# 1         178  SÃO GONÇALO  237.0  -6.835777 -38.311583  A333  São Gonçalo
# 2         178  SÃO GONÇALO  237.0  -6.835777 -38.311583  A333  São Gonçalo
# 3         178  SÃO GONÇALO  237.0  -6.835777 -38.311583  A333  São Gonçalo
# 4         178  SÃO GONÇALO  237.0  -6.835777 -38.311583  A333  São Gonçalo
# ...       ...          ...    ...        ...        ...   ...          ...
# 9779163   423      BARUERI  777.0 -23.523890 -46.869450  A755      Barueri
# 9779164   423      BARUERI  777.0 -23.523890 -46.869450  A755      Barueri
# 9779165   423      BARUERI  777.0 -23.523890 -46.869450  A755      Barueri
# 9779166   423      BARUERI  777.0 -23.523890 -46.869450  A755      Barueri
# 9779167   423      BARUERI  777.0 -23.523890 -46.869450  A755      Barueri
#
# ...

# %%
df.shape
# Out:
# (9779168, 31)

# %%
df=pd.read_csv(sudeste.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7366df1f1143> in <module>
# ----> 1 df=pd.read_csv(sudeste.csv)
#
# NameError: name 'sudeste' is not defined

# %%
df=pd.read_csv('sudeste.csv')

# %%
df.shape
# Out:
# (9779168, 31)
